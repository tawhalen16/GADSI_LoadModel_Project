# %%
##### MODELING LIBRARIES #####
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.random import set_seed
from keras.callbacks import EarlyStopping

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from patsy import dmatrices, dmatrix

##### FORMATTING AND GRAPHING LIBRARIES #####
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

##### TIMING AND UTILITY LIBRARIES #####
from datetime import datetime
import timeit
from dateutil.relativedelta import relativedelta 
import random

# %%
# MAPE function taken from:
# https://www.statology.org/mape-python/
def mape(actual, pred): 
    actual, pred = np.array(actual), np.array(pred)
    return np.mean(np.abs((actual - pred) / actual)) * 100

# %%
##### IMPORT PREPARED DATA #####
print('Reading pre-built dataset...')
df_full = pd.read_csv('../PJM_Weekly_Model/sample_base_data.csv', index_col = 0, parse_dates = [0])

# Drop all lag columns for use in RNN
lag_sq_cols = [column for column in df_full.columns if 'Lag' in column]
df_full = df_full.drop(columns = lag_sq_cols)

# Infill remaining nulls (from missing daylight savings hour) with previous value
backfilled = df_full.isna().sum().sum()
print('Backfilling %s null values...'%(backfilled))
df_full = df_full.fillna(method = 'backfill')

# Convert date, time, holiday columns to categorical variables
for col in ['Month','WeekDay','Day','Hour']:
    df_full[col] = df_full[col].astype('category')
    
# Create dataframe for actual loads and predicted train and test values
df_train = pd.DataFrame(df_full['value'])
df_test = pd.DataFrame(df_full['value'])
# Out:
# Reading pre-built dataset...
# Backfilling 1 null values...

# %%
df_full.columns
# Out:
# Index(['value', 'WWP', 'THI', 'Light', 'WWPSq', 'THISq', 'Month', 'Day',
#        'WeekDay', 'Hour', 'Holiday'],
#       dtype='object')

# %%
# Define final parameters
param_dict = {'seq_length':12,
              'seq_batch_size':256,
              'layer_one_neurons':128,
              'layer_two_neurons':32,
              'layer_three_neurons':16,
              'layer_four_neurons':16,
              'dropout_rate':0,
              'stop_patience':4,
              'learning_rate':0.01,
              'epochs':40
             }

# %%
##### RNN ON MOVING TRAINING WINDOW #####
tic = timeit.default_timer()
print("\nDefining training set, building and training models...")

# Define shift variable for taking moving sample of data
data_shift = 0

# while data_shift + 18240 < df_full.shape[0]:
while data_shift == 0 :
    ##### FINAL DATA PREPARATION #####
    
    # Limit dataset to roughly 13 months of data (18240 hours)
    df_modeling = df_full.iloc[data_shift:18240 + data_shift,:].copy()
    
    # Use Patsy to create the one-hot encoded dummy variables with interactions 
    y, X =  dmatrices('value~Light+WWP+THI+WWPSq+THISq+Month+Day+WeekDay+Hour+Holiday',df_modeling,return_type='dataframe')

    # Split data into training and testing data sets with two-year training sample (8760 h/yr * 2)
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 17520 / X.shape[0], shuffle = False)

    # Standardize both datasets - create fit to use on backcast dataset
    ss = StandardScaler()

    X_train_ss = ss.fit_transform(X_train)
    X_test_ss = ss.transform(X_test)
    
    # Limit dataset to roughly 13 months of data (18240 hours)
    df_modeling = df_full.iloc[data_shift:18240 + data_shift,:].copy()

    # Set random seed
    random.seed(283)
    set_seed(283)

    # Create output dataframes for individual predictions
    df_preds_train = pd.DataFrame()
    df_preds_test = pd.DataFrame()

    for x in range(5):
        # Create training sequences
        train_sequences = TimeseriesGenerator(X_train_ss, y_train['value'],
                                              length = param_dict['seq_length'],
                                              batch_size = param_dict['seq_batch_size'])

        # Create test sequences
        test_sequences = TimeseriesGenerator(X_test_ss, y_test['value']
                                             ,length = param_dict['seq_length']
                                             ,batch_size = param_dict['seq_batch_size'])

        ##### RNN MODEL #####
        # Instantiate model and construct all layers
        model = Sequential()
        model.add(GRU(param_dict['layer_one_neurons'], input_shape = (param_dict['seq_length'],77),
                      return_sequences = True, activation = 'relu', ))
        model.add(Dropout(param_dict['dropout_rate']))
        model.add(GRU(param_dict['layer_two_neurons'], return_sequences = True, activation = 'relu'))
        model.add(Dropout(param_dict['dropout_rate']))
        model.add(GRU(param_dict['layer_three_neurons'], return_sequences = True, activation = 'relu'))
        model.add(Dropout(param_dict['dropout_rate']))
        model.add(GRU(param_dict['layer_four_neurons'], return_sequences = False, activation = 'relu'))
        model.add(Dropout(param_dict['dropout_rate']))
        model.add(Dense(1, activation = 'linear'))

        # Compile and fit model
        model.compile(optimizer = Adam(learning_rate = param_dict['learning_rate']),
                      loss = 'mean_squared_error',
                      metrics = 'mean_absolute_percentage_error')

        early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience = param_dict['stop_patience'], verbose=1, mode='auto')

        model.fit(train_sequences,
                  validation_data = test_sequences,
                  epochs = param_dict['epochs'],
                  callbacks = [early_stop],
                  verbose = True)

        # Write predictions to dataframe, adding nulls equal to lag
        df_preds_train[x] = np.append([np.NaN] * param_dict['seq_length'], model.predict(train_sequences).transpose())
        df_preds_test[x] = np.append([np.NaN] * param_dict['seq_length'], model.predict(test_sequences).transpose())

    # Define name for current model as first date of the testing dataset
    model_date = datetime.date(X_test.index[0])
    
    # Create ensemble prediction and add to final output dataframes
    # NOTE: This would be a good spot for future improvement by creating weighting for the ensemble models
    y_train[model_date] = df_preds_train.mean(axis=1).tolist()
    y_test[model_date] = df_preds_test.mean(axis=1).tolist()
    
    # Output model results
    print('\n%s Model Results' % (model_date))
    
    # Create mask to exclude all records with null values for the give dataset
    mask_train = (y_train[model_date].notna())
    mask_test = (y_test[model_date].notna())
    
    # Calculate r2 scores for training and testing data
    train_r2 = round(r2_score(y_train.loc[mask_train, model_date],y_train.loc[mask_train, 'value']),3)
    test_r2 = round(r2_score(y_test.loc[mask_test, model_date],y_test.loc[mask_test, 'value']),3)
    print('Training data r2: %s' % (train_r2))
    print('Testing data r2: %s' % (test_r2))

    # Calculate MAPE scores for training and testing data
    train_mape = round(mape(y_train.loc[mask_train, model_date],y_train.loc[mask_train, 'value']),3)
    test_mape = round(mape(y_test.loc[mask_test, model_date],y_test.loc[mask_test, 'value']),3)
    print('Training data MAPE: %s' % (train_mape))
    print('Testing data MAPE: %s' % (test_mape))

    # Add the model predictions to the respective dataframes
    df_train = pd.merge(df_train, y_train.drop(columns = 'value'), how = 'left', left_index = True, right_index = True)
    df_test = pd.merge(df_test, y_test.drop(columns = 'value'), how = 'left', left_index = True, right_index = True)
    
    # Increment the data shift by one week (168 hours)
    data_shift += 168

toc = timeit.default_timer()
print('\nAll RNN fits completed in %0.2f seconds' % (toc-tic))
# Out:
# Defining training set, building and training models...
# Epoch 1/40
# 69/69 [==============================] - 3s 39ms/step - loss: 6828176896.0000 - mean_absolute_percentage_error: 82.9582 - val_loss: 6388581888.0000 - val_mean_absolute_percentage_error: 80.9774
# Epoch 2/40
# 69/69 [==============================] - 2s 34ms/step - loss: 2905822720.0000 - mean_absolute_percentage_error: 50.8676 - val_loss: 2544660224.0000 - val_mean_absolute_percentage_error: 48.5641
# Epoch 3/40
# 69/69 [==============================] - 2s 34ms/step - loss: 595330496.0000 - mean_absolute_percentage_error: 21.0658 - val_loss: 1372236800.0000 - val_mean_absolute_percentage_error: 35.5618
# Epoch 4/40
# 69/69 [==============================] - 2s 34ms/step - loss: 365060864.0000 - mean_absolute_percentage_error: 17.2352 - val_loss: 252980384.0000 - val_mean_absolute_percentage_error: 14.2862
# Epoch 5/40
# 69/69 [==============================] - 2s 34ms/step - loss: 169442240.0000 - mean_absolute_percentage_error: 11.2757 - val_loss: 271315520.0000 - val_mean_absolute_percentage_error: 14.1647
# Epoch 6/40
# 69/69 [==============================] - 2s 34ms/step - loss: 69414616.0000 - mean_absolute_percentage_error: 7.0895 - val_loss: 161339456.0000 - val_mean_absolute_percentage_error: 10.3928
# Epoch 7/40
# 69/69 [==============================] - 2s 34ms/step - loss: 70996464.0000 - mean_absolute_percentage_error: 7.2844 - val_loss: 65416388.0000 - val_mean_absolute_percentage_error: 7.0889
# Epoch 8/40
# 69/69 [==============================] - 2s 34ms/step - loss: 53781128.0000 - mean_absolute_percentage_error: 6.4348 - val_loss: 74731800.0000 - val_mean_absolute_percentage_error: 7.4821
# Epoch 9/40
# 69/69 [==============================] - 2s 34ms/step - loss: 56916208.0000 - mean_absolute_percentage_error: 6.5734 - val_loss: 43067276.0000 - val_mean_absolute_percentage_error: 5.3490
# Epoch 10/40
# 69/69 [==============================] - 2s 34ms/step - loss: 33778144.0000 - mean_absolute_percentage_error: 4.9135 - val_loss: 34128696.0000 - val_mean_absolute_percentage_error: 4.5230
# Epoch 11/40
# 69/69 [==============================] - 2s 34ms/step - loss: 62388348.0000 - mean_absolute_percentage_error: 6.5869 - val_loss: 140996048.0000 - val_mean_absolute_percentage_error: 10.2575
# Epoch 12/40
# 69/69 [==============================] - 2s 34ms/step - loss: 161203776.0000 - mean_absolute_percentage_error: 11.5682 - val_loss: 165356848.0000 - val_mean_absolute_percentage_error: 12.2541
# Epoch 13/40
# 69/69 [==============================] - 2s 34ms/step - loss: 117491168.0000 - mean_absolute_percentage_error: 9.2437 - val_loss: 46554708.0000 - val_mean_absolute_percentage_error: 5.8179
# Epoch 14/40
# 69/69 [==============================] - 2s 34ms/step - loss: 109429456.0000 - mean_absolute_percentage_error: 8.9650 - val_loss: 42315028.0000 - val_mean_absolute_percentage_error: 5.4035
# Epoch 00014: early stopping
# Epoch 1/40
# 69/69 [==============================] - 3s 41ms/step - loss: 7544431104.0000 - mean_absolute_percentage_error: 87.4742 - val_loss: 8381633024.0000 - val_mean_absolute_percentage_error: 92.7578
# Epoch 2/40
# 69/69 [==============================] - 2s 36ms/step - loss: 4083682048.0000 - mean_absolute_percentage_error: 62.0094 - val_loss: 886699584.0000 - val_mean_absolute_percentage_error: 26.0330
# Epoch 3/40
# 69/69 [==============================] - 2s 36ms/step - loss: 1371706240.0000 - mean_absolute_percentage_error: 33.3468 - val_loss: 206528320.0000 - val_mean_absolute_percentage_error: 10.8074
# Epoch 4/40
# 69/69 [==============================] - 2s 35ms/step - loss: 189738800.0000 - mean_absolute_percentage_error: 12.0229 - val_loss: 188460192.0000 - val_mean_absolute_percentage_error: 10.5291
# Epoch 5/40
# 69/69 [==============================] - 2s 36ms/step - loss: 125513904.0000 - mean_absolute_percentage_error: 9.5554 - val_loss: 267868768.0000 - val_mean_absolute_percentage_error: 13.3625
# Epoch 6/40
# 69/69 [==============================] - 2s 35ms/step - loss: 141988000.0000 - mean_absolute_percentage_error: 10.2384 - val_loss: 151802592.0000 - val_mean_absolute_percentage_error: 9.9650
# Epoch 7/40
# 69/69 [==============================] - 2s 36ms/step - loss: 82620208.0000 - mean_absolute_percentage_error: 7.6467 - val_loss: 71860192.0000 - val_mean_absolute_percentage_error: 7.0991
# Epoch 8/40
# 69/69 [==============================] - 2s 36ms/step - loss: 73027352.0000 - mean_absolute_percentage_error: 7.1573 - val_loss: 97371432.0000 - val_mean_absolute_percentage_error: 7.8721
# Epoch 9/40
# 69/69 [==============================] - 3s 36ms/step - loss: 52657212.0000 - mean_absolute_percentage_error: 6.2509 - val_loss: 50816920.0000 - val_mean_absolute_percentage_error: 5.4502
# Epoch 10/40
# 69/69 [==============================] - 2s 36ms/step - loss: 56431140.0000 - mean_absolute_percentage_error: 6.3252 - val_loss: 40232452.0000 - val_mean_absolute_percentage_error: 5.2003
# Epoch 11/40
# 69/69 [==============================] - 2s 36ms/step - loss: 48389428.0000 - mean_absolute_percentage_error: 6.0026 - val_loss: 107006528.0000 - val_mean_absolute_percentage_error: 8.3652
# Epoch 12/40
# 69/69 [==============================] - 2s 36ms/step - loss: 91682384.0000 - mean_absolute_percentage_error: 8.4786 - val_loss: 43199620.0000 - val_mean_absolute_percentage_error: 5.4811
# Epoch 13/40
# 69/69 [==============================] - 2s 36ms/step - loss: 149496640.0000 - mean_absolute_percentage_error: 10.8056 - val_loss: 237796064.0000 - val_mean_absolute_percentage_error: 14.4994
# Epoch 14/40
# 69/69 [==============================] - 3s 36ms/step - loss: 804969152.0000 - mean_absolute_percentage_error: 25.3681 - val_loss: 453766624.0000 - val_mean_absolute_percentage_error: 19.4265
# Epoch 00014: early stopping
# Epoch 1/40
# 69/69 [==============================] - 3s 39ms/step - loss: 7103032832.0000 - mean_absolute_percentage_error: 85.7445 - val_loss: 7885039104.0000 - val_mean_absolute_percentage_error: 90.1112
# Epoch 2/40
# 69/69 [==============================] - 2s 31ms/step - loss: 2130598656.0000 - mean_absolute_percentage_error: 41.9341 - val_loss: 706494720.0000 - val_mean_absolute_percentage_error: 24.2971
# Epoch 3/40
# 69/69 [==============================] - 2s 31ms/step - loss: 494593344.0000 - mean_absolute_percentage_error: 19.9296 - val_loss: 154327312.0000 - val_mean_absolute_percentage_error: 9.9368
# Epoch 4/40
# 69/69 [==============================] - 2s 31ms/step - loss: 160811232.0000 - mean_absolute_percentage_error: 11.0250 - val_loss: 266247264.0000 - val_mean_absolute_percentage_error: 13.7393
# Epoch 5/40
# 69/69 [==============================] - 2s 31ms/step - loss: 146484272.0000 - mean_absolute_percentage_error: 10.3324 - val_loss: 237217056.0000 - val_mean_absolute_percentage_error: 14.3416
# Epoch 6/40
# 69/69 [==============================] - 2s 31ms/step - loss: 244654832.0000 - mean_absolute_percentage_error: 14.1323 - val_loss: 193917568.0000 - val_mean_absolute_percentage_error: 11.6313
# Epoch 7/40
# 69/69 [==============================] - 2s 31ms/step - loss: 274329440.0000 - mean_absolute_percentage_error: 14.7048 - val_loss: 150853152.0000 - val_mean_absolute_percentage_error: 10.0702
# Epoch 8/40
# 69/69 [==============================] - 2s 31ms/step - loss: 192183936.0000 - mean_absolute_percentage_error: 11.7490 - val_loss: 275348000.0000 - val_mean_absolute_percentage_error: 15.4266
# Epoch 9/40
# 69/69 [==============================] - 2s 32ms/step - loss: 112107896.0000 - mean_absolute_percentage_error: 9.0946 - val_loss: 80227808.0000 - val_mean_absolute_percentage_error: 6.8663
# Epoch 10/40
# 69/69 [==============================] - 2s 32ms/step - loss: 99940904.0000 - mean_absolute_percentage_error: 8.7123 - val_loss: 60700012.0000 - val_mean_absolute_percentage_error: 6.5521
# Epoch 11/40
# 69/69 [==============================] - 2s 31ms/step - loss: 70511760.0000 - mean_absolute_percentage_error: 6.9326 - val_loss: 56361076.0000 - val_mean_absolute_percentage_error: 6.0052
# Epoch 12/40
# 69/69 [==============================] - 2s 31ms/step - loss: 73268536.0000 - mean_absolute_percentage_error: 7.6872 - val_loss: 176837328.0000 - val_mean_absolute_percentage_error: 12.0136
# Epoch 13/40
# 69/69 [==============================] - 2s 32ms/step - loss: 481012192.0000 - mean_absolute_percentage_error: 18.9373 - val_loss: 1613108224.0000 - val_mean_absolute_percentage_error: 39.8078
# Epoch 14/40
# 69/69 [==============================] - 2s 32ms/step - loss: 544949632.0000 - mean_absolute_percentage_error: 20.0847 - val_loss: 196421568.0000 - val_mean_absolute_percentage_error: 11.6382
# Epoch 15/40
# 69/69 [==============================] - 2s 32ms/step - loss: 139499696.0000 - mean_absolute_percentage_error: 10.0932 - val_loss: 140006736.0000 - val_mean_absolute_percentage_error: 8.8581
# Epoch 00015: early stopping
# Epoch 1/40
# 69/69 [==============================] - 3s 37ms/step - loss: 12488180736.0000 - mean_absolute_percentage_error: 78.1598 - val_loss: 454772832.0000 - val_mean_absolute_percentage_error: 16.3243
# Epoch 2/40
# 69/69 [==============================] - 2s 33ms/step - loss: 363372736.0000 - mean_absolute_percentage_error: 16.5468 - val_loss: 555348544.0000 - val_mean_absolute_percentage_error: 21.1522
# Epoch 3/40
# 69/69 [==============================] - 2s 33ms/step - loss: 248370096.0000 - mean_absolute_percentage_error: 13.2161 - val_loss: 215171120.0000 - val_mean_absolute_percentage_error: 11.4205
# Epoch 4/40
# 69/69 [==============================] - 2s 33ms/step - loss: 338070208.0000 - mean_absolute_percentage_error: 16.4753 - val_loss: 335211328.0000 - val_mean_absolute_percentage_error: 15.2711
# Epoch 5/40
# 69/69 [==============================] - 2s 33ms/step - loss: 252636928.0000 - mean_absolute_percentage_error: 13.6088 - val_loss: 115441048.0000 - val_mean_absolute_percentage_error: 8.0819
# Epoch 6/40
# 69/69 [==============================] - 2s 33ms/step - loss: 118533280.0000 - mean_absolute_percentage_error: 9.3012 - val_loss: 98240248.0000 - val_mean_absolute_percentage_error: 7.4464
# Epoch 7/40
# 69/69 [==============================] - 2s 33ms/step - loss: 125537392.0000 - mean_absolute_percentage_error: 9.8378 - val_loss: 315551040.0000 - val_mean_absolute_percentage_error: 15.8254
# Epoch 8/40
# 69/69 [==============================] - 2s 33ms/step - loss: 120843168.0000 - mean_absolute_percentage_error: 9.4243 - val_loss: 89530520.0000 - val_mean_absolute_percentage_error: 7.1462
# Epoch 9/40
# 69/69 [==============================] - 2s 33ms/step - loss: 72191696.0000 - mean_absolute_percentage_error: 7.2553 - val_loss: 94786736.0000 - val_mean_absolute_percentage_error: 8.0079
# Epoch 10/40
# 69/69 [==============================] - 2s 33ms/step - loss: 138143824.0000 - mean_absolute_percentage_error: 10.0972 - val_loss: 80580448.0000 - val_mean_absolute_percentage_error: 7.5283
# Epoch 11/40
# 69/69 [==============================] - 2s 33ms/step - loss: 86522832.0000 - mean_absolute_percentage_error: 7.8115 - val_loss: 58727344.0000 - val_mean_absolute_percentage_error: 5.4510
# Epoch 12/40
# 69/69 [==============================] - 2s 33ms/step - loss: 87574792.0000 - mean_absolute_percentage_error: 7.8295 - val_loss: 740369984.0000 - val_mean_absolute_percentage_error: 25.8547
# Epoch 13/40
# 69/69 [==============================] - 2s 33ms/step - loss: 251336000.0000 - mean_absolute_percentage_error: 13.5204 - val_loss: 287320608.0000 - val_mean_absolute_percentage_error: 15.4783
# Epoch 14/40
# 69/69 [==============================] - 2s 33ms/step - loss: 128900176.0000 - mean_absolute_percentage_error: 9.8195 - val_loss: 63680876.0000 - val_mean_absolute_percentage_error: 6.2134
# Epoch 15/40
# 69/69 [==============================] - 2s 33ms/step - loss: 61663516.0000 - mean_absolute_percentage_error: 6.8329 - val_loss: 41205040.0000 - val_mean_absolute_percentage_error: 4.8251
# Epoch 16/40
# 69/69 [==============================] - 2s 33ms/step - loss: 75013000.0000 - mean_absolute_percentage_error: 7.6902 - val_loss: 73461728.0000 - val_mean_absolute_percentage_error: 6.3588
# Epoch 17/40
# 69/69 [==============================] - 2s 33ms/step - loss: 51008200.0000 - mean_absolute_percentage_error: 6.0294 - val_loss: 49924100.0000 - val_mean_absolute_percentage_error: 5.4204
# Epoch 18/40
# 69/69 [==============================] - 2s 33ms/step - loss: 42488464.0000 - mean_absolute_percentage_error: 5.6055 - val_loss: 45483032.0000 - val_mean_absolute_percentage_error: 5.1783
# Epoch 19/40
# 69/69 [==============================] - 2s 33ms/step - loss: 43308032.0000 - mean_absolute_percentage_error: 5.4668 - val_loss: 35111176.0000 - val_mean_absolute_percentage_error: 4.6957
# Epoch 20/40
# 69/69 [==============================] - 2s 33ms/step - loss: 42486388.0000 - mean_absolute_percentage_error: 5.6209 - val_loss: 42123356.0000 - val_mean_absolute_percentage_error: 5.3766
# Epoch 21/40
# 69/69 [==============================] - 2s 33ms/step - loss: 66345556.0000 - mean_absolute_percentage_error: 6.9655 - val_loss: 63432380.0000 - val_mean_absolute_percentage_error: 6.2342
# Epoch 22/40
# 69/69 [==============================] - 2s 33ms/step - loss: 185507504.0000 - mean_absolute_percentage_error: 11.1629 - val_loss: 479584672.0000 - val_mean_absolute_percentage_error: 20.4911
# Epoch 23/40
# 69/69 [==============================] - 2s 33ms/step - loss: 194732016.0000 - mean_absolute_percentage_error: 12.3141 - val_loss: 107947776.0000 - val_mean_absolute_percentage_error: 9.2896
# Epoch 00023: early stopping
# Epoch 1/40
# 69/69 [==============================] - 2s 35ms/step - loss: 42863812608.0000 - mean_absolute_percentage_error: 120.5987 - val_loss: 8565254656.0000 - val_mean_absolute_percentage_error: 94.0832
# Epoch 2/40
# 69/69 [==============================] - 2s 30ms/step - loss: 3665442048.0000 - mean_absolute_percentage_error: 59.0705 - val_loss: 767926336.0000 - val_mean_absolute_percentage_error: 23.9110
# Epoch 3/40
# 69/69 [==============================] - 2s 30ms/step - loss: 716653056.0000 - mean_absolute_percentage_error: 22.3658 - val_loss: 465543584.0000 - val_mean_absolute_percentage_error: 19.3156
# Epoch 4/40
# 69/69 [==============================] - 2s 30ms/step - loss: 235664016.0000 - mean_absolute_percentage_error: 13.2165 - val_loss: 104234280.0000 - val_mean_absolute_percentage_error: 7.8843
# Epoch 5/40
# 69/69 [==============================] - 2s 29ms/step - loss: 164889504.0000 - mean_absolute_percentage_error: 11.1796 - val_loss: 138979328.0000 - val_mean_absolute_percentage_error: 9.2649
# Epoch 6/40
# 69/69 [==============================] - 2s 30ms/step - loss: 120821816.0000 - mean_absolute_percentage_error: 9.3614 - val_loss: 132843024.0000 - val_mean_absolute_percentage_error: 9.2740
# Epoch 7/40
# 69/69 [==============================] - 2s 30ms/step - loss: 116930592.0000 - mean_absolute_percentage_error: 9.3466 - val_loss: 116170856.0000 - val_mean_absolute_percentage_error: 8.5972
# Epoch 8/40
# 69/69 [==============================] - 2s 30ms/step - loss: 110808976.0000 - mean_absolute_percentage_error: 8.7771 - val_loss: 85910896.0000 - val_mean_absolute_percentage_error: 7.4197
# Epoch 9/40
# 69/69 [==============================] - 2s 30ms/step - loss: 113327984.0000 - mean_absolute_percentage_error: 9.1610 - val_loss: 75120976.0000 - val_mean_absolute_percentage_error: 6.9257
# Epoch 10/40
# 69/69 [==============================] - 2s 30ms/step - loss: 82455320.0000 - mean_absolute_percentage_error: 7.6708 - val_loss: 97663024.0000 - val_mean_absolute_percentage_error: 8.0709
# Epoch 11/40
# 69/69 [==============================] - 2s 30ms/step - loss: 73235952.0000 - mean_absolute_percentage_error: 7.3167 - val_loss: 57927288.0000 - val_mean_absolute_percentage_error: 6.2656
# Epoch 12/40
# 69/69 [==============================] - 2s 29ms/step - loss: 67064516.0000 - mean_absolute_percentage_error: 6.9630 - val_loss: 48069400.0000 - val_mean_absolute_percentage_error: 5.7607
# Epoch 13/40
# 69/69 [==============================] - 2s 30ms/step - loss: 62131016.0000 - mean_absolute_percentage_error: 6.7411 - val_loss: 57963392.0000 - val_mean_absolute_percentage_error: 6.0668
# Epoch 14/40
# 69/69 [==============================] - 2s 30ms/step - loss: 96360760.0000 - mean_absolute_percentage_error: 8.3948 - val_loss: 67022028.0000 - val_mean_absolute_percentage_error: 6.5839
# Epoch 15/40
# 69/69 [==============================] - 2s 29ms/step - loss: 58569280.0000 - mean_absolute_percentage_error: 6.5082 - val_loss: 44174268.0000 - val_mean_absolute_percentage_error: 5.5893
# Epoch 16/40
# 69/69 [==============================] - 2s 29ms/step - loss: 75757472.0000 - mean_absolute_percentage_error: 7.6207 - val_loss: 89064776.0000 - val_mean_absolute_percentage_error: 8.0012
# Epoch 17/40
# 69/69 [==============================] - 2s 29ms/step - loss: 71665072.0000 - mean_absolute_percentage_error: 7.4136 - val_loss: 41039848.0000 - val_mean_absolute_percentage_error: 5.2251
# Epoch 18/40
# 69/69 [==============================] - 2s 29ms/step - loss: 45373720.0000 - mean_absolute_percentage_error: 5.7602 - val_loss: 67033632.0000 - val_mean_absolute_percentage_error: 6.7361
# Epoch 19/40
# 69/69 [==============================] - 2s 29ms/step - loss: 52323536.0000 - mean_absolute_percentage_error: 6.1197 - val_loss: 44251620.0000 - val_mean_absolute_percentage_error: 5.3779
# Epoch 20/40
# 69/69 [==============================] - 2s 29ms/step - loss: 49469440.0000 - mean_absolute_percentage_error: 6.0666 - val_loss: 35385696.0000 - val_mean_absolute_percentage_error: 4.8250
# Epoch 21/40
# 69/69 [==============================] - 2s 29ms/step - loss: 38938184.0000 - mean_absolute_percentage_error: 5.4118 - val_loss: 124627600.0000 - val_mean_absolute_percentage_error: 9.7010
# Epoch 22/40
# 69/69 [==============================] - 2s 29ms/step - loss: 52763268.0000 - mean_absolute_percentage_error: 6.2965 - val_loss: 66831424.0000 - val_mean_absolute_percentage_error: 6.7900
# Epoch 23/40
# 69/69 [==============================] - 2s 29ms/step - loss: 54128176.0000 - mean_absolute_percentage_error: 6.3885 - val_loss: 67349224.0000 - val_mean_absolute_percentage_error: 6.8775
# Epoch 24/40
# 69/69 [==============================] - 2s 30ms/step - loss: 47458848.0000 - mean_absolute_percentage_error: 5.9548 - val_loss: 52303940.0000 - val_mean_absolute_percentage_error: 6.1845
# Epoch 00024: early stopping
#
# 2018-12-31 Model Results
# Training data r2: 0.791
# Testing data r2: 0.482
# Training data MAPE: 5.759
# Testing data MAPE: 5.176
#
# All RNN fits completed in 224.34 seconds
# C:\Users\tawha\anaconda3\lib\site-packages\ipykernel_launcher.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\tawha\anaconda3\lib\site-packages\ipykernel_launcher.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
